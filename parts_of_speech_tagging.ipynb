# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
paragraph="Adolf Hitler was a German political leader who ruled Germany from 1933 to 1945. He led the Nazi Party and established a dictatorship based on extreme nationalism, racism, and authoritarian control. His policies caused World War II and led to the Holocaust, in which millions of Jews and others were systematically murdered. Hitler’s actions resulted in massive destruction, loss of life, and long-lasting global consequences. Today, he is remembered as a warning of how dangerous extremist ideology and unchecked power can be."

# %%
# For each & every word in the paragraph above, determine whats the part of speech

# %%
sentences=nltk.sent_tokenize(paragraph)

# %%
for i in sentences:
    print(i)
# Out:
# Adolf Hitler was a German political leader who ruled Germany from 1933 to 1945.
# He led the Nazi Party and established a dictatorship based on extreme nationalism, racism, and authoritarian control.
# His policies caused World War II and led to the Holocaust, in which millions of Jews and others were systematically murdered.
# Hitler’s actions resulted in massive destruction, loss of life, and long-lasting global consequences.
# Today, he is remembered as a warning of how dangerous extremist ideology and unchecked power can be.

# %%
# Find out the pos tags

nltk.pos_tag(sentences)
# Out:
# [('Adolf Hitler was a German political leader who ruled Germany from 1933 to 1945.',
#   'NNP'),
#  ('He led the Nazi Party and established a dictatorship based on extreme nationalism, racism, and authoritarian control.',
#   'NNP'),
#  ('His policies caused World War II and led to the Holocaust, in which millions of Jews and others were systematically murdered.',
#   'NNP'),
#  ('Hitler’s actions resulted in massive destruction, loss of life, and long-lasting global consequences.',
#   'NNP'),
#  ('Today, he is remembered as a warning of how dangerous extremist ideology and unchecked power can be.',
#   'NNP')]

# %%
for i in range(len(sentences)):
    word=nltk.word_tokenize(sentences[i])
    print(nltk.pos_tag(word))
# Out:
# [('Adolf', 'NNP'), ('Hitler', 'NNP'), ('was', 'VBD'), ('a', 'DT'), ('German', 'JJ'), ('political', 'JJ'), ('leader', 'NN'), ('who', 'WP'), ('ruled', 'VBD'), ('Germany', 'NNP'), ('from', 'IN'), ('1933', 'CD'), ('to', 'TO'), ('1945', 'CD'), ('.', '.')]
# [('He', 'PRP'), ('led', 'VBD'), ('the', 'DT'), ('Nazi', 'NNP'), ('Party', 'NNP'), ('and', 'CC'), ('established', 'VBD'), ('a', 'DT'), ('dictatorship', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('extreme', 'JJ'), ('nationalism', 'NN'), (',', ','), ('racism', 'NN'), (',', ','), ('and', 'CC'), ('authoritarian', 'JJ'), ('control', 'NN'), ('.', '.')]
# [('His', 'PRP$'), ('policies', 'NNS'), ('caused', 'VBD'), ('World', 'NNP'), ('War', 'NNP'), ('II', 'NNP'), ('and', 'CC'), ('led', 'VBD'), ('to', 'TO'), ('the', 'DT'), ('Holocaust', 'NNP'), (',', ','), ('in', 'IN'), ('which', 'WDT'), ('millions', 'NNS'), ('of', 'IN'), ('Jews', 'NNP'), ('and', 'CC'), ('others', 'NNS'), ('were', 'VBD'), ('systematically', 'RB'), ('murdered', 'VBN'), ('.', '.')]
# [('Hitler', 'NNP'), ('’', 'NNP'), ('s', 'VBD'), ('actions', 'NNS'), ('resulted', 'VBD'), ('in', 'IN'), ('massive', 'JJ'), ('destruction', 'NN'), (',', ','), ('loss', 'NN'), ('of', 'IN'), ('life', 'NN'), (',', ','), ('and', 'CC'), ('long-lasting', 'JJ'), ('global', 'JJ'), ('consequences', 'NNS'), ('.', '.')]
# [('Today', 'NN'), (',', ','), ('he', 'PRP'), ('is', 'VBZ'), ('remembered', 'VBN'), ('as', 'IN'), ('a', 'DT'), ('warning', 'NN'), ('of', 'IN'), ('how', 'WRB'), ('dangerous', 'JJ'), ('extremist', 'NN'), ('ideology', 'NN'), ('and', 'CC'), ('unchecked', 'JJ'), ('power', 'NN'), ('can', 'MD'), ('be', 'VB'), ('.', '.')]

# %%
name='Swaraj Kumar Sahoo'
name_list=name.split()
nltk.pos_tag(name_list)
# Out:
# [('Swaraj', 'NNP'), ('Kumar', 'NNP'), ('Sahoo', 'NNP')]
